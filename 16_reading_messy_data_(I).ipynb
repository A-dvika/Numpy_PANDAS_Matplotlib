# %%
import pandas as pd

# %%
pd.read_csv("E:\igdtu1\data\cars_raw.csv")
# Out:
#                                           Welcome    to            the  \
# Feel    free  to         analyze  and       clean   the          messy
# 18.0   8     307.0      130.0 hp 3504        12.0    70  United States
# 15.0   8     350.0      165.0 hp 3693        11.5    70  United States
# 18.0   8     318.0      150.0 hp 3436        11.0    70  United States
# 16.0   8     304.0      150.0 hp 3433        12.0    70            usa
# ...                                           ...   ...            ...
# 27.0   4     101.0      83.0 hp  2202        15.3    76         europe
# 17.0   6     250.0      100.0 hp 3329        15.5    71            usa
# 14.5   8     351.0      152.0 hp 4215        12.8    76            usa
# 25.0   6     181.0      110.0 hp 2945        16.4    82            usa
# Thanks  for   analyzing  this     Dataset       !   NaN            NaN
#
#                                                                    cars  \
# ...

# %%
labels = ['mpg',
 'cylinders',
 'displacement',
 'horsepower',
 'weight',
 'acceleration',
 'model year',
 'origin',
 'name']

# %%
#complete the code and run the cell!
pd.read_csv("E:\igdtu1\data\cars_raw.csv", skiprows= 2, skipfooter= 1, header = None, names = labels)
# Out:
# <ipython-input-4-ef62fbfd4a09>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   pd.read_csv("E:\igdtu1\data\cars_raw.csv", skiprows= 2, skipfooter= 1, header = None, names = labels)
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0   130.0 hp    3504          12.0
# 1    15.0          8         350.0   165.0 hp    3693          11.5
# 2    18.0          8         318.0   150.0 hp    3436          11.0
# 3    16.0          8         304.0   150.0 hp    3433          12.0
# 4    17.0          8         302.0   140.0 hp    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 324  12.0          8         429.0   198.0 hp    4952          11.5
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# ...

# %%
cars=pd.read_csv("E:\igdtu1\data\cars_raw.csv", skiprows= 2, skipfooter= 1, header = None, names = labels)
# Out:
# <ipython-input-5-24a77cdb8c92>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   cars=pd.read_csv("E:\igdtu1\data\cars_raw.csv", skiprows= 2, skipfooter= 1, header = None, names = labels)

# %%
# run the cell!
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
# 2  18.0          8         318.0   150.0 hp    3436          11.0          70
# 3  16.0          8         304.0   150.0 hp    3433          12.0          70
# 4  17.0          8         302.0   140.0 hp    3449          10.5          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320
# 2  United States           plymouth satellite
# 3            usa                amc rebel sst
# 4            usa                  FORD TORINO

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0   130.0 hp    3504          12.0
# 1    15.0          8         350.0   165.0 hp    3693          11.5
# 2    18.0          8         318.0   150.0 hp    3436          11.0
# 3    16.0          8         304.0   150.0 hp    3433          12.0
# 4    17.0          8         302.0   140.0 hp    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 324  12.0          8         429.0   198.0 hp    4952          11.5
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# 326  17.0          6         250.0   100.0 hp    3329          15.5
# 327  14.5          8         351.0   152.0 hp    4215          12.8
# 328  25.0          6         181.0   110.0 hp    2945          16.4
#
#      model year         origin                          name
# 0            70  United States    chevrolet chevelle malibu
# ...

# %%
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 324  12.0          8         429.0   198.0 hp    4952          11.5
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# 326  17.0          6         250.0   100.0 hp    3329          15.5
# 327  14.5          8         351.0   152.0 hp    4215          12.8
# 328  25.0          6         181.0   110.0 hp    2945          16.4
#
#      model year  origin                          name
# 324          73     usa     mercury marquis brougham
# 325          76  europe                 renault 12tl
# 326          71     usa    chevrolet chevelle malibu
# 327          76     usa             ford gran torino
# 328          82     usa        buick century limited

# %%
cars.to_csv("E:\igdtu1\data\cars_impp.csv")

# %%
cars.to_csv("cars_imp.csv", index= False)

# %%
pd.read_csv("E:\igdtu1\data\cars_impp.csv")
# Out:
#      Unnamed: 0   mpg  cylinders  displacement horsepower  weight  \
# 0             0  18.0          8         307.0   130.0 hp    3504
# 1             1  15.0          8         350.0   165.0 hp    3693
# 2             2  18.0          8         318.0   150.0 hp    3436
# 3             3  16.0          8         304.0   150.0 hp    3433
# 4             4  17.0          8         302.0   140.0 hp    3449
# ..          ...   ...        ...           ...        ...     ...
# 324         324  12.0          8         429.0   198.0 hp    4952
# 325         325  27.0          4         101.0    83.0 hp    2202
# 326         326  17.0          6         250.0   100.0 hp    3329
# 327         327  14.5          8         351.0   152.0 hp    4215
# 328         328  25.0          6         181.0   110.0 hp    2945
#
#      acceleration  model year         origin                          name
# 0            12.0          70  United States    chevrolet chevelle malibu
# ...

# %%
cars.to_csv("E:\igdtu1\data\cars_impp2.csv",index= False)

# %%
pd.read_csv("E:\igdtu1\data\cars_impp2.csv")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0   130.0 hp    3504          12.0
# 1    15.0          8         350.0   165.0 hp    3693          11.5
# 2    18.0          8         318.0   150.0 hp    3436          11.0
# 3    16.0          8         304.0   150.0 hp    3433          12.0
# 4    17.0          8         302.0   140.0 hp    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 324  12.0          8         429.0   198.0 hp    4952          11.5
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# 326  17.0          6         250.0   100.0 hp    3329          15.5
# 327  14.5          8         351.0   152.0 hp    4215          12.8
# 328  25.0          6         181.0   110.0 hp    2945          16.4
#
#      model year         origin                          name
# 0            70  United States    chevrolet chevelle malibu
# ...

# %% [markdown]
# ----------------------------
